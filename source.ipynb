# %% [markdown]
# # EDA

# %%
from src.EDA import *

# %%
LABELS_BASE_PATH = "data/goose2D/goose_2d_train/labels/train"
IMAGES_BASE_PATH = "data/goose2D/goose_2d_train/images/train"

# %%
LABELS_BASE_PATH = "data/goose2D/goose_2d_train/labels/train"
IMAGES_BASE_PATH = "data/goose2D/goose_2d_train/images/train"
df = scan_labels(LABELS_BASE_PATH)
print(df.head())

pixel_stats, presence_stats = run_eda_stats(df)
print("Distribución de píxeles por clase:")
for i, count in enumerate(pixel_stats):
    print(f"Clase {i}: {count} píxeles")
# Out:
#                                                 path           sequence  \
# 0  data/goose2D/goose_2d_train/labels/train/2022-...  2022-07-22_flight
# 1  data/goose2D/goose_2d_train/labels/train/2022-...  2022-07-22_flight
# 2  data/goose2D/goose_2d_train/labels/train/2022-...  2022-07-22_flight
# 3  data/goose2D/goose_2d_train/labels/train/2022-...  2022-07-22_flight
# 4  data/goose2D/goose_2d_train/labels/train/2022-...  2022-07-22_flight
#
#                                             filename
# 0  2022-07-22_flight__0345_1658495633153999033_la...
# 1  2022-07-22_flight__0333_1658495521867577081_la...
# 2  2022-07-22_flight__0025_1658493656829200501_la...
# 3  2022-07-22_flight__0032_1658493856234465044_la...
# 4  2022-07-22_flight__0340_1658495545529967168_la...
# Iniciando análisis de distribución de etiquetas...
# 100%|██████████| 7845/7845 [02:01<00:00, 64.33it/s]
# Distribución de píxeles por clase:
# Clase 0: 12053148 píxeles
# Clase 1: 13171 píxeles
# Clase 2: 320760570 píxeles
# Clase 3: 102854343 píxeles
# Clase 4: 41963952 píxeles
# Clase 5: 238425760 píxeles
# Clase 6: 10525135 píxeles
# Clase 7: 731310 píxeles
# Clase 8: 204121419 píxeles
# Clase 9: 0 píxeles
# Clase 10: 1055547 píxeles
# Clase 11: 46740199 píxeles
# Clase 12: 136367240 píxeles
# Clase 13: 1775662 píxeles
# Clase 14: 3456606 píxeles
# Clase 15: 4633723 píxeles
# Clase 16: 3332550588 píxeles
# Clase 17: 1122488837 píxeles
# Clase 18: 13779710 píxeles
# Clase 19: 3525693 píxeles
# Clase 20: 469111 píxeles
# Clase 21: 105318316 píxeles
# Clase 22: 45604828 píxeles
# Clase 23: 1911712149 píxeles
# Clase 24: 846706273 píxeles
# Clase 25: 1228639 píxeles
# Clase 26: 768866 píxeles
# Clase 27: 860703945 píxeles
# Clase 28: 665915338 píxeles
# Clase 29: 65863763 píxeles
# Clase 30: 175544747 píxeles
# Clase 31: 176612293 píxeles
# Clase 32: 884133 píxeles
# Clase 33: 206935 píxeles
# Clase 34: 7418888 píxeles
# Clase 35: 2382179 píxeles
# Clase 36: 3780077 píxeles
# Clase 37: 2460291 píxeles
# Clase 38: 378936432 píxeles
# Clase 39: 32499742 píxeles
# Clase 40: 3916332 píxeles
# Clase 41: 318313538 píxeles
# Clase 42: 21314694 píxeles
# Clase 43: 19221140 píxeles
# Clase 44: 3518320 píxeles
# Clase 45: 29451667 píxeles
# Clase 46: 16330303 píxeles
# Clase 47: 16162575 píxeles
# Clase 48: 700429 píxeles
# Clase 49: 42472 píxeles
# Clase 50: 1876082218 píxeles
# Clase 51: 798004899 píxeles
# Clase 52: 1376589 píxeles
# Clase 53: 1964900778 píxeles
# Clase 54: 15428336 píxeles
# Clase 55: 11249718 píxeles
# Clase 56: 58 píxeles
# Clase 57: 4512670 píxeles
# Clase 58: 7696453 píxeles
# Clase 59: 74485529 píxeles
# Clase 60: 1199 píxeles
# Clase 61: 1852 píxeles
# Clase 62: 1008673 píxeles
# Clase 63: 0 píxeles

# %% [markdown]
# ## **Inspección Visual**:
# Cruce de imágenes RGB con sus máscaras correspondientes para observar la complejidad de los entornos reales.

# %%
visual_inspection(LABELS_BASE_PATH, IMAGES_BASE_PATH, num_samples=3)
# Out:
# Error: No se encontró 2022-09-14_garching_uebungsplatz__0394_1663154812246307922_vis.png en data/goose2D/goose_2d_train/images/train/2022-09-14_garching_uebungsplatz
# Error: No se encontró 2022-09-14_garching_uebungsplatz__0216_1663154078113298162_vis.png en data/goose2D/goose_2d_train/images/train/2022-09-14_garching_uebungsplatz
# Error: No se encontró 2022-12-07_aying_hills__0304_1670423276647800445_vis.png en data/goose2D/goose_2d_train/images/train/2022-12-07_aying_hills
